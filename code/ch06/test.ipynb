# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = a
b *= 2
print(a)
print(a is b)
# Out:
# [2 4 6]
# True

# %%
a = np.array([1, 2, 3])
b = a
b = b * 2
print(a)
print(a is b)
# Out:
# [1 2 3]
# False
