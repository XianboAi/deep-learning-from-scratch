# %%
import numpy as np

# %%
x = np.array([[1, 2],
              [3, 4]])

# %%
print(x.shape)
# Out:
# (2, 2)

# %%
mask = x >= 0
print(mask.shape)
# Out:
# (2, 2)

# %%
out = x[mask]
print(out.shape)
# Out:
# (4,)
